# %% [markdown]
# ### Cox Regression
#
# maybe "https://lifelines.readthedocs.io/en/latest/index.html"
# # Dependent Variables:
# - Company survival
#
# # Independent Variables:
# - Population density
# - ...
