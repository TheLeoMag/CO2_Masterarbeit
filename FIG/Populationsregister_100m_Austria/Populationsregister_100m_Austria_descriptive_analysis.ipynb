# %% [markdown]
# # Bevölkerungsregister: 100-m-Raster Österreich
#
# Univariate descriptive analysis for the master's thesis.
#
# **Source:** OGD/pd_popreg_100m_7767c33f-302c-11e3-beb4-0000c1ab0db6.geoparquet

# %%
import os
import sys
os.chdir(r"D:\CO2_Masterarbeit\CO2_Masterarbeit")
sys.path.insert(0, r"D:\CO2_Masterarbeit\CO2_Masterarbeit\FIG")

import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
from plotting.apa7 import set_apa7_style, new_figure, save_apa7, BAR_KWARGS, HIST_KWARGS, LINE_KWARGS

set_apa7_style()

# %%
population = gpd.read_parquet("OGD/pd_popreg_100m_7767c33f-302c-11e3-beb4-0000c1ab0db6.geoparquet")
print(f"Populated 100-m cells: {len(population):,}")
population["population"].describe()
# Out:
# Populated 100-m cells: 588,603
# count    588603.000000
# mean         15.625495
# std          35.310705
# min           1.000000
# 25%           3.000000
# 50%           6.000000
# 75%          14.000000
# max        1295.000000
# Name: population, dtype: float64

# %% [markdown]
# ## Population per populated 100-m cell
#
# Only populated cells are included in this extract.

# %%
fig, ax = new_figure()
ax.hist(population["population"], bins=40, **HIST_KWARGS)
ax.set_xscale("log")
ax.set(xlabel="Population per 100-m cell (log scale)", ylabel="Frequency")
save_apa7(fig, "FIG/Populationsregister_100m_Austria/figure_1_population_per_cell.png")
save_apa7(fig, "FIG/Populationsregister_100m_Austria/figure_1_population_per_cell.svg")
plt.show()
